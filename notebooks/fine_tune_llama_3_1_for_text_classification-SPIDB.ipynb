# %% [markdown]
# ## Setting up

# %%
# %%capture
# %pip install -U bitsandbytes
# %pip install -U transformers
# %pip install -U accelerate
# %pip install -U peft
# %pip install -U trl

# %%
# import wandb

# from kaggle_secrets import UserSecretsClient
# user_secrets = UserSecretsClient()

# wb_token = user_secrets.get_secret("wandb")

# wandb.login(key=wb_token)
# run = wandb.init(
#     project='Fine-tune llama-3.1-8b-it on Sentiment Analysis Dataset',
#     job_type="training",
#     anonymous="allow"
# )

# %%
import numpy as np
import pandas as pd
import os
from tqdm import tqdm
import bitsandbytes as bnb
import torch
import torch.nn as nn
import transformers
from datasets import Dataset
from peft import LoraConfig, PeftConfig
from trl import SFTTrainer
from trl import setup_chat_format
from transformers import (AutoModelForCausalLM,
                          AutoTokenizer,
                          BitsAndBytesConfig,
                          TrainingArguments,
                          pipeline,
                          logging)
from sklearn.metrics import (accuracy_score,
                             classification_report,
                             confusion_matrix)
from sklearn.model_selection import train_test_split
# Out:
# /root/miniconda3/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/root/miniconda3/lib/python3.10/site-packages/torchvision/image.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %% [markdown]
# ## Loading and processing the dataset

# %%
# %pwd
# Out:
# '/root/autodl-tmp'

# %%
neg = pd.read_csv(r'/root/reinforcement_commit/datasets/ffmpeg.csv')
pos = pd.read_csv(r'/root/reinforcement_commit/datasets/qemu.csv', encoding='utf_8_sig')
df = pd.concat([neg[['commit_msg','patch','vulnerability']],pos[['commit_msg','patch','vulnerability']]],axis=0)
df.fillna('', inplace=True)
# 1是100%的意思
df = df.sample(frac=1, random_state=42).reset_index(drop=True)
df.rename(columns={'vulnerability':'label','patch':'diff','commit_msg':'message'},inplace=True)
label2id={0:'negative',1:'positive'}
df = df.replace({"label": label2id})
df =  df[df['diff'].str.len()<1024]
df
# Out:
#                                                  message  \
# 2       MIPS: fix yield handling The parameter for yi...
# 3       jvdec: avoid unsigned overflow in comparison ...
# 6       target-ppc: Bug Fix: mulldo OV Detection Fix ...
# 8       do boundary check based on absolute value (Gl...
# 13      ide/isa: Replace unchecked qdev_init() by qde...
# ...                                                  ...
# 25863   s390-ccw.img: Detect devices with stsch. stsc...
# 25864   faxcompr: fix out of array read Signed-off-by...
# 25868   migration: don't close a file descriptor whil...
# 25870   Fix headers so that "make checkheaders" passe...
# 25872   lm32: fix build breakage due to uninitialized...
#
#                                                     diff     label
# 2      diff --git a/target-mips/op_helper.c b/target-...  negative
# 3      diff --git a/libavformat/jvdec.c b/libavformat...  positive
# 6      diff --git a/target-ppc/int_helper.c b/target-...  positive
# 8      diff --git a/hw/cirrus_vga.c b/hw/cirrus_vga.c...  positive
# 13     diff --git a/hw/ide/isa.c b/hw/ide/isa.c\ninde...  positive
# ...                                                  ...       ...
# 25863  diff --git a/pc-bios/s390-ccw/main.c b/pc-bios...  negative
# 25864  diff --git a/libavcodec/faxcompr.c b/libavcode...  negative
# 25868  diff --git a/migration/migration.c b/migration...  positive
# 25870  diff --git a/libavcodec/amr.h b/libavcodec/amr...  negative
# 25872  diff --git a/hw/milkymist-pfpu.c b/hw/milkymis...  positive
#
# [12825 rows x 3 columns]

# %%
# Shuffle the DataFrame and select only 3000 rows
df = df.sample(frac=1, random_state=85).reset_index(drop=True).head(3000)

# Split the DataFrame
train_size = 0.8
eval_size = 0.1

# Calculate sizes
train_end = int(train_size * len(df))
eval_end = train_end + int(eval_size * len(df))

# Split the data
X_train = df[:train_end]
X_eval = df[train_end:eval_end]
X_test = df[eval_end:]

# Define the prompt generation functions
def generate_prompt(data_point):
    return f"""
            Classify the text into negative, positive, and return the answer as the corresponding security patch identification label.
text: {data_point["diff"]}
label: {data_point["label"]}""".strip()

def generate_test_prompt(data_point):
    return f"""
            Classify the text into negative, positive, and return the answer as the corresponding security patch identification label.
text: {data_point["diff"]}
label: """.strip()

# Generate prompts for training and evaluation data
X_train.loc[:,'text'] = X_train.apply(generate_prompt, axis=1)
X_eval.loc[:,'text'] = X_eval.apply(generate_prompt, axis=1)

# Generate test prompts and extract true labels
y_true = X_test.loc[:,'label']
X_test = pd.DataFrame(X_test.apply(generate_test_prompt, axis=1), columns=["text"])
# Out:
# /tmp/ipykernel_2280/176985973.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.loc[:,'text'] = X_train.apply(generate_prompt, axis=1)
# /tmp/ipykernel_2280/176985973.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_eval.loc[:,'text'] = X_eval.apply(generate_prompt, axis=1)

# %%
X_train.label.value_counts()
# Out:
# label
# negative    1269
# positive    1131
# Name: count, dtype: int64

# %%
y_true.value_counts()
# Out:
# label
# negative    158
# positive    142
# Name: count, dtype: int64

# %%
# Convert to datasets
train_data = Dataset.from_pandas(X_train[["text"]])
eval_data = Dataset.from_pandas(X_eval[["text"]])

# %%
train_data['text'][3]
# Out:
# 'Classify the text into negative, positive, and return the answer as the corresponding security patch identification label.\ntext: diff --git a/libavformat/rtpdec_h264.c b/libavformat/rtpdec_h264.c\r\nindex b399be4..e707d03 100644\r\n--- a/libavformat/rtpdec_h264.c\r\n+++ b/libavformat/rtpdec_h264.c\r\n@@ -166,6 +166,10 @@ static int sdp_parse_fmtp_config_h264(AVFormatContext *s,\r\n             parse_profile_level_id(s, h264_data, value);\r\n     } else if (!strcmp(attr, "sprop-parameter-sets")) {\r\n         int ret;\r\n+        if (value[strlen(value) - 1] == \',\') {\r\n+            av_log(s, AV_LOG_WARNING, "Missing PPS in sprop-parameter-sets, ignoring\\n");\r\n+            return 0;\r\n+        }\r\n         codec->extradata_size = 0;\r\n         av_freep(&codec->extradata);\r\n         ret = ff_h264_parse_sprop_parameter_sets(s, &codec->extradata,\r\n\nlabel: negative'

# %% [markdown]
# ## Loading the model and tokenizer

# %%
base_model_name = "/root/autodl-tmp/models/Llama3"

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=False,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype="float16",
)

model = AutoModelForCausalLM.from_pretrained(
    base_model_name,
    device_map="auto",
    torch_dtype="float16",
    quantization_config=bnb_config,
)

model.config.use_cache = False
model.config.pretraining_tp = 1
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
tokenizer = AutoTokenizer.from_pretrained(base_model_name)

tokenizer.pad_token_id = tokenizer.eos_token_id

# %% [markdown]
# ## Model evalution before fine-tuning

# %%
def predict(test, model, tokenizer):
    y_pred = []
    categories = ["negative", "positive"]

    for i in tqdm(range(len(test))):
        prompt = test.iloc[i]["text"]
        pipe = pipeline(task="text-generation",
                        model=model,
                        tokenizer=tokenizer,
                        max_new_tokens=2,
                        temperature=0.1)

        result = pipe(prompt)
        answer = result[0]['generated_text'].split("label:")[-1].strip()

        # Determine the predicted category
        for category in categories:
            if category.lower() in answer.lower():
                y_pred.append(category)
                break
        else:
            y_pred.append("none")

    return y_pred

# %%
y_pred = predict(X_test, model, tokenizer)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]Device set to use cuda:0
#   0%|          | 1/300 [00:00<03:34,  1.39it/s]Device set to use cuda:0
#   1%|          | 2/300 [00:00<01:52,  2.64it/s]Device set to use cuda:0
#   1%|          | 3/300 [00:01<01:20,  3.69it/s]Device set to use cuda:0
#   1%|▏         | 4/300 [00:01<01:06,  4.43it/s]Device set to use cuda:0
#   2%|▏         | 5/300 [00:01<00:59,  4.97it/s]Device set to use cuda:0
#   2%|▏         | 6/300 [00:01<00:54,  5.43it/s]Device set to use cuda:0
#   2%|▏         | 7/300 [00:01<00:49,  5.89it/s]Device set to use cuda:0
#   3%|▎         | 8/300 [00:01<00:47,  6.10it/s]Device set to use cuda:0
#   3%|▎         | 9/300 [00:01<00:46,  6.30it/s]Device set to use cuda:0
#   3%|▎         | 10/300 [00:02<00:46,  6.26it/s]Device set to use cuda:0
#   4%|▎         | 11/300 [00:02<00:46,  6.20it/s]Device set to use cuda:0
#   4%|▍         | 12/300 [00:02<00:44,  6.46it/s]Device set to use cuda:0
#   4%|▍         | 13/300 [00:02<00:42,  6.69it/s]Device set to use cuda:0
#   5%|▍         | 14/300 [00:02<00:43,  6.65it/s]Device set to use cuda:0
#   5%|▌         | 15/300 [00:02<00:42,  6.77it/s]Device set to use cuda:0
#   5%|▌         | 16/300 [00:02<00:43,  6.60it/s]Device set to use cuda:0
#   6%|▌         | 17/300 [00:03<00:42,  6.68it/s]Device set to use cuda:0
#   6%|▌         | 18/300 [00:03<00:42,  6.59it/s]Device set to use cuda:0
#   6%|▋         | 19/300 [00:03<00:43,  6.42it/s]Device set to use cuda:0
#   7%|▋         | 20/300 [00:03<00:42,  6.62it/s]Device set to use cuda:0
#   7%|▋         | 21/300 [00:03<00:41,  6.77it/s]Device set to use cuda:0
#   7%|▋         | 22/300 [00:03<00:40,  6.90it/s]Device set to use cuda:0
#   8%|▊         | 23/300 [00:03<00:40,  6.85it/s]Device set to use cuda:0
#   8%|▊         | 24/300 [00:04<00:41,  6.68it/s]Device set to use cuda:0
#   8%|▊         | 25/300 [00:04<00:38,  7.10it/s]Device set to use cuda:0
#   9%|▊         | 26/300 [00:04<00:36,  7.53it/s]Device set to use cuda:0
#   9%|▉         | 27/300 [00:04<00:34,  7.89it/s]Device set to use cuda:0
#   9%|▉         | 28/300 [00:04<00:33,  8.20it/s]Device set to use cuda:0
#  10%|▉         | 29/300 [00:04<00:32,  8.27it/s]Device set to use cuda:0
#  10%|█         | 30/300 [00:04<00:33,  8.08it/s]Device set to use cuda:0
#  10%|█         | 31/300 [00:04<00:34,  7.84it/s]Device set to use cuda:0
#  11%|█         | 32/300 [00:05<00:32,  8.21it/s]Device set to use cuda:0
#  11%|█         | 33/300 [00:05<00:32,  8.34it/s]Device set to use cuda:0
#  11%|█▏        | 34/300 [00:05<00:31,  8.46it/s]Device set to use cuda:0
#  12%|█▏        | 35/300 [00:05<00:31,  8.52it/s]Device set to use cuda:0
#  12%|█▏        | 36/300 [00:05<00:30,  8.64it/s]Device set to use cuda:0
#  12%|█▏        | 37/300 [00:05<00:30,  8.60it/s]Device set to use cuda:0
#  13%|█▎        | 38/300 [00:05<00:32,  8.04it/s]Device set to use cuda:0
#  13%|█▎        | 39/300 [00:05<00:31,  8.20it/s]Device set to use cuda:0
#  13%|█▎        | 40/300 [00:06<00:31,  8.31it/s]Device set to use cuda:0
#  14%|█▎        | 41/300 [00:06<00:30,  8.50it/s]Device set to use cuda:0
#  14%|█▍        | 42/300 [00:06<00:30,  8.44it/s]Device set to use cuda:0
#  14%|█▍        | 43/300 [00:06<00:31,  8.21it/s]Device set to use cuda:0
#  15%|█▍        | 44/300 [00:06<00:32,  7.88it/s]Device set to use cuda:0
#  15%|█▌        | 45/300 [00:06<00:31,  8.22it/s]Device set to use cuda:0
#  85%|████████▌ | 256/300 [00:34<00:05,  7.85it/s]Device set to use cuda:0
#  86%|████████▌ | 257/300 [00:34<00:05,  7.70it/s]Device set to use cuda:0
#  86%|████████▌ | 258/300 [00:34<00:05,  7.98it/s]Device set to use cuda:0
#  86%|████████▋ | 259/300 [00:34<00:05,  8.08it/s]Device set to use cuda:0
#  87%|████████▋ | 260/300 [00:34<00:04,  8.06it/s]Device set to use cuda:0
#  87%|████████▋ | 261/300 [00:34<00:05,  7.54it/s]Device set to use cuda:0
#  87%|████████▋ | 262/300 [00:34<00:05,  7.26it/s]Device set to use cuda:0
#  88%|████████▊ | 263/300 [00:35<00:05,  7.33it/s]Device set to use cuda:0
#  88%|████████▊ | 264/300 [00:35<00:04,  7.68it/s]Device set to use cuda:0
#  88%|████████▊ | 265/300 [00:35<00:04,  7.88it/s]Device set to use cuda:0
#  89%|████████▊ | 266/300 [00:35<00:04,  8.04it/s]Device set to use cuda:0
#  89%|████████▉ | 267/300 [00:35<00:04,  7.80it/s]Device set to use cuda:0
#  89%|████████▉ | 268/300 [00:35<00:03,  8.09it/s]Device set to use cuda:0
#  90%|████████▉ | 269/300 [00:35<00:03,  8.27it/s]Device set to use cuda:0
#  90%|█████████ | 270/300 [00:35<00:03,  8.34it/s]Device set to use cuda:0
#  90%|█████████ | 271/300 [00:36<00:03,  8.47it/s]Device set to use cuda:0
#  91%|█████████ | 272/300 [00:36<00:03,  8.62it/s]Device set to use cuda:0
#  91%|█████████ | 273/300 [00:36<00:03,  8.78it/s]Device set to use cuda:0
#  91%|█████████▏| 274/300 [00:36<00:02,  8.75it/s]Device set to use cuda:0
#  92%|█████████▏| 275/300 [00:36<00:02,  8.66it/s]Device set to use cuda:0
#  92%|█████████▏| 276/300 [00:36<00:02,  8.81it/s]Device set to use cuda:0
#  92%|█████████▏| 277/300 [00:36<00:02,  8.40it/s]Device set to use cuda:0
#  93%|█████████▎| 278/300 [00:36<00:02,  8.51it/s]Device set to use cuda:0
#  93%|█████████▎| 279/300 [00:36<00:02,  8.18it/s]Device set to use cuda:0
#  93%|█████████▎| 280/300 [00:37<00:02,  8.44it/s]Device set to use cuda:0
#  94%|█████████▎| 281/300 [00:37<00:02,  8.51it/s]Device set to use cuda:0
#  94%|█████████▍| 282/300 [00:37<00:02,  8.51it/s]Device set to use cuda:0
#  94%|█████████▍| 283/300 [00:37<00:02,  8.18it/s]Device set to use cuda:0
#  95%|█████████▍| 284/300 [00:37<00:01,  8.32it/s]Device set to use cuda:0
#  95%|█████████▌| 285/300 [00:37<00:01,  8.44it/s]Device set to use cuda:0
#  95%|█████████▌| 286/300 [00:37<00:01,  8.58it/s]Device set to use cuda:0
#  96%|█████████▌| 287/300 [00:37<00:01,  8.64it/s]Device set to use cuda:0
#  96%|█████████▌| 288/300 [00:38<00:01,  8.59it/s]Device set to use cuda:0
#  96%|█████████▋| 289/300 [00:38<00:01,  7.95it/s]Device set to use cuda:0
#  97%|█████████▋| 290/300 [00:38<00:01,  8.30it/s]Device set to use cuda:0
#  97%|█████████▋| 291/300 [00:38<00:01,  8.29it/s]Device set to use cuda:0
#  97%|█████████▋| 292/300 [00:38<00:00,  8.47it/s]Device set to use cuda:0
#  98%|█████████▊| 293/300 [00:38<00:00,  8.60it/s]Device set to use cuda:0
#  98%|█████████▊| 294/300 [00:38<00:00,  7.97it/s]Device set to use cuda:0
#  98%|█████████▊| 295/300 [00:38<00:00,  8.14it/s]Device set to use cuda:0
#  99%|█████████▊| 296/300 [00:39<00:00,  8.38it/s]Device set to use cuda:0
#  99%|█████████▉| 297/300 [00:39<00:00,  8.49it/s]Device set to use cuda:0
#  99%|█████████▉| 298/300 [00:39<00:00,  8.44it/s]Device set to use cuda:0
# 100%|█████████▉| 299/300 [00:39<00:00,  8.55it/s]Device set to use cuda:0
# 100%|██████████| 300/300 [00:39<00:00,  7.60it/s]

# %%
def evaluate(y_true, y_pred):
    labels = ["negative", "positive"]
    mapping = {label: idx for idx, label in enumerate(labels)}

    def map_func(x):
        return mapping.get(x, -1)  # Map to -1 if not found, but should not occur with correct data

    y_true_mapped = np.vectorize(map_func)(y_true)
    y_pred_mapped = np.vectorize(map_func)(y_pred)

    # Calculate accuracy
    accuracy = accuracy_score(y_true=y_true_mapped, y_pred=y_pred_mapped)
    print(f'Accuracy: {accuracy:.3f}')

    # Generate accuracy report
    unique_labels = set(y_true_mapped)  # Get unique labels

    for label in unique_labels:
        label_indices = [i for i in range(len(y_true_mapped)) if y_true_mapped[i] == label]
        label_y_true = [y_true_mapped[i] for i in label_indices]
        label_y_pred = [y_pred_mapped[i] for i in label_indices]
        label_accuracy = accuracy_score(label_y_true, label_y_pred)
        print(f'Accuracy for label {labels[label]}: {label_accuracy:.3f}')

    # Generate classification report
    class_report = classification_report(y_true=y_true_mapped, y_pred=y_pred_mapped, target_names=labels, digits=4, labels=list(range(len(labels))))
    print('\nClassification Report:')
    print(class_report)

    # Generate confusion matrix
    conf_matrix = confusion_matrix(y_true=y_true_mapped, y_pred=y_pred_mapped, labels=list(range(len(labels))))
    print('\nConfusion Matrix:')
    print(conf_matrix)

# %%
evaluate(y_true, y_pred)
# Out:
# Accuracy: 0.530
# Accuracy for label negative: 0.671
# Accuracy for label positive: 0.373
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative     0.5436    0.6709    0.6006       158
#     positive     0.5048    0.3732    0.4291       142
#
#     accuracy                         0.5300       300
#    macro avg     0.5242    0.5221    0.5149       300
# weighted avg     0.5252    0.5300    0.5194       300
#
#
# Confusion Matrix:
# [[106  52]
#  [ 89  53]]

# %% [markdown]
# ## Extracting the linear modules names

# %%
import bitsandbytes as bnb

def find_all_linear_names(model):
    cls = bnb.nn.Linear4bit
    lora_module_names = set()
    for name, module in model.named_modules():
        if isinstance(module, cls):
            names = name.split('.')
            lora_module_names.add(names[0] if len(names) == 1 else names[-1])
    if 'lm_head' in lora_module_names:  # needed for 16 bit
        lora_module_names.remove('lm_head')
    return list(lora_module_names)

# %%
modules = find_all_linear_names(model)
modules
# Out:
# ['base_layer']

# %% [markdown]
# ## Setting up the model

# %%
output_dir="llama-3.1-fine-tuned-model"

peft_config = LoraConfig(
    lora_alpha=16,
    lora_dropout=0,
    r=64,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=modules,
)

training_arguments = TrainingArguments(
    output_dir=output_dir,                    # directory to save and repository id
    num_train_epochs=1,                       # number of training epochs
    per_device_train_batch_size=1,            # batch size per device during training
    gradient_accumulation_steps=8,            # number of steps before performing a backward/update pass
    gradient_checkpointing=True,              # use gradient checkpointing to save memory
    optim="paged_adamw_32bit",
    logging_steps=1,
    learning_rate=2e-4,                       # learning rate, based on QLoRA paper
    weight_decay=0.001,
    fp16=True,
    bf16=False,
    max_grad_norm=0.3,                        # max gradient norm based on QLoRA paper
    max_steps=-1,
    warmup_ratio=0.03,                        # warmup ratio based on QLoRA paper
    group_by_length=False,
    lr_scheduler_type="cosine",               # use cosine learning rate scheduler
    report_to="none",                  # report metrics to w&b
    eval_strategy="steps",              # save checkpoint every epoch
    eval_steps = 0.2
)

trainer = SFTTrainer(
    model=model,
    args=training_arguments,
    train_dataset=train_data,
    eval_dataset=eval_data,
    peft_config=peft_config,
    processing_class=tokenizer
)
# Out:
# Adding EOS to train dataset:   0%|          | 0/2400 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/2400 [00:00<?, ? examples/s]
# Truncating train dataset:   0%|          | 0/2400 [00:00<?, ? examples/s]
# Adding EOS to eval dataset:   0%|          | 0/300 [00:00<?, ? examples/s]
# Tokenizing eval dataset:   0%|          | 0/300 [00:00<?, ? examples/s]
# Truncating eval dataset:   0%|          | 0/300 [00:00<?, ? examples/s]

# %% [markdown]
# ## Model Training

# %%
# Train model
trainer.train()
# Out:
#     <div>
#
#       <progress value='300' max='300' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [300/300 24:30, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>60</td>
#       <td>1.038100</td>
#       <td>1.094074</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>1.008500</td>
#       <td>1.069437</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.999100</td>
#       <td>1.050757</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>1.125500</td>
#       <td>1.039348</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.956400</td>
#       <td>1.036687</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=300, training_loss=1.082589714328448, metrics={'train_runtime': 1475.434, 'train_samples_per_second': 1.627, 'train_steps_per_second': 0.203, 'total_flos': 2.5538663477673984e+16, 'train_loss': 1.082589714328448})

# %%
# wandb.finish()
model.config.use_cache = True

# %% [markdown]
# ## Saving the model and tokenizer

# %%
# Save trained model and tokenizer
trainer.save_model(output_dir)
tokenizer.save_pretrained(output_dir)
# Out:
# ('llama-3.1-fine-tuned-model/tokenizer_config.json',
#  'llama-3.1-fine-tuned-model/special_tokens_map.json',
#  'llama-3.1-fine-tuned-model/chat_template.jinja',
#  'llama-3.1-fine-tuned-model/tokenizer.json')

# %% [markdown]
# ## Testing model after fine-tuning

# %%
y_pred = predict(X_test, model, tokenizer)
evaluate(y_true, y_pred)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]Device set to use cuda:0
#   0%|          | 1/300 [00:00<01:51,  2.69it/s]Device set to use cuda:0
#   1%|          | 2/300 [00:00<01:39,  2.99it/s]Device set to use cuda:0
#   1%|          | 3/300 [00:00<01:28,  3.35it/s]Device set to use cuda:0
#   1%|▏         | 4/300 [00:01<01:24,  3.49it/s]Device set to use cuda:0
#   2%|▏         | 5/300 [00:01<01:26,  3.43it/s]Device set to use cuda:0
#   2%|▏         | 6/300 [00:01<01:27,  3.36it/s]Device set to use cuda:0
#   2%|▏         | 7/300 [00:02<01:28,  3.31it/s]Device set to use cuda:0
#   3%|▎         | 8/300 [00:02<01:25,  3.41it/s]Device set to use cuda:0
#   3%|▎         | 9/300 [00:02<01:23,  3.49it/s]Device set to use cuda:0
#   3%|▎         | 10/300 [00:02<01:22,  3.51it/s]Device set to use cuda:0
#   4%|▎         | 11/300 [00:03<01:24,  3.42it/s]Device set to use cuda:0
#   4%|▍         | 12/300 [00:03<01:21,  3.52it/s]Device set to use cuda:0
#   4%|▍         | 13/300 [00:03<01:20,  3.55it/s]Device set to use cuda:0
#   5%|▍         | 14/300 [00:04<01:22,  3.47it/s]Device set to use cuda:0
#   5%|▌         | 15/300 [00:04<01:19,  3.57it/s]Device set to use cuda:0
#   5%|▌         | 16/300 [00:04<01:16,  3.72it/s]Device set to use cuda:0
#   6%|▌         | 17/300 [00:04<01:10,  3.99it/s]Device set to use cuda:0
#   6%|▌         | 18/300 [00:05<01:05,  4.32it/s]Device set to use cuda:0
#   6%|▋         | 19/300 [00:05<01:02,  4.46it/s]Device set to use cuda:0
#   7%|▋         | 20/300 [00:05<01:01,  4.56it/s]Device set to use cuda:0
#   7%|▋         | 21/300 [00:05<01:01,  4.57it/s]Device set to use cuda:0
#   7%|▋         | 22/300 [00:05<01:01,  4.48it/s]Device set to use cuda:0
#   8%|▊         | 23/300 [00:06<00:59,  4.64it/s]Device set to use cuda:0
#   8%|▊         | 24/300 [00:06<01:02,  4.39it/s]Device set to use cuda:0
#   8%|▊         | 25/300 [00:06<01:05,  4.20it/s]Device set to use cuda:0
#   9%|▊         | 26/300 [00:06<01:07,  4.09it/s]Device set to use cuda:0
#   9%|▉         | 27/300 [00:07<01:07,  4.02it/s]Device set to use cuda:0
#   9%|▉         | 28/300 [00:07<01:08,  3.96it/s]Device set to use cuda:0
#  10%|▉         | 29/300 [00:07<01:13,  3.67it/s]Device set to use cuda:0
#  10%|█         | 30/300 [00:07<01:12,  3.72it/s]Device set to use cuda:0
#  79%|███████▊  | 236/300 [00:57<00:12,  5.04it/s]Device set to use cuda:0
#  79%|███████▉  | 237/300 [00:57<00:12,  5.00it/s]Device set to use cuda:0
#  79%|███████▉  | 238/300 [00:57<00:12,  5.04it/s]Device set to use cuda:0
#  80%|███████▉  | 239/300 [00:58<00:12,  5.08it/s]Device set to use cuda:0
#  80%|████████  | 240/300 [00:58<00:11,  5.04it/s]Device set to use cuda:0
#  80%|████████  | 241/300 [00:58<00:11,  5.09it/s]Device set to use cuda:0
#  81%|████████  | 242/300 [00:58<00:11,  5.04it/s]Device set to use cuda:0
#  81%|████████  | 243/300 [00:58<00:11,  4.99it/s]Device set to use cuda:0
#  81%|████████▏ | 244/300 [00:59<00:11,  4.86it/s]Device set to use cuda:0
#  82%|████████▏ | 245/300 [00:59<00:11,  4.74it/s]Device set to use cuda:0
#  82%|████████▏ | 246/300 [00:59<00:11,  4.82it/s]Device set to use cuda:0
#  82%|████████▏ | 247/300 [00:59<00:10,  4.93it/s]Device set to use cuda:0
#  83%|████████▎ | 248/300 [00:59<00:10,  4.91it/s]Device set to use cuda:0
#  83%|████████▎ | 249/300 [01:00<00:10,  4.83it/s]Device set to use cuda:0
#  83%|████████▎ | 250/300 [01:00<00:11,  4.49it/s]Device set to use cuda:0
#  84%|████████▎ | 251/300 [01:00<00:11,  4.22it/s]Device set to use cuda:0
#  84%|████████▍ | 252/300 [01:00<00:11,  4.06it/s]Device set to use cuda:0
#  84%|████████▍ | 253/300 [01:01<00:11,  3.93it/s]Device set to use cuda:0
#  85%|████████▍ | 254/300 [01:01<00:11,  3.91it/s]Device set to use cuda:0
#  85%|████████▌ | 255/300 [01:01<00:11,  3.86it/s]Device set to use cuda:0
#  85%|████████▌ | 256/300 [01:02<00:11,  3.81it/s]Device set to use cuda:0
#  86%|████████▌ | 257/300 [01:02<00:11,  3.82it/s]Device set to use cuda:0
#  86%|████████▌ | 258/300 [01:02<00:11,  3.78it/s]Device set to use cuda:0
#  86%|████████▋ | 259/300 [01:02<00:10,  3.75it/s]Device set to use cuda:0
#  87%|████████▋ | 260/300 [01:03<00:10,  3.78it/s]Device set to use cuda:0
#  87%|████████▋ | 261/300 [01:03<00:10,  3.78it/s]Device set to use cuda:0
#  87%|████████▋ | 262/300 [01:03<00:10,  3.70it/s]Device set to use cuda:0
#  88%|████████▊ | 263/300 [01:03<00:10,  3.64it/s]Device set to use cuda:0
#  88%|████████▊ | 264/300 [01:04<00:09,  3.95it/s]Device set to use cuda:0
#  88%|████████▊ | 265/300 [01:04<00:08,  4.26it/s]Device set to use cuda:0
#  89%|████████▊ | 266/300 [01:04<00:07,  4.44it/s]Device set to use cuda:0
#  89%|████████▉ | 267/300 [01:04<00:07,  4.47it/s]Device set to use cuda:0
#  89%|████████▉ | 268/300 [01:04<00:06,  4.68it/s]Device set to use cuda:0
#  90%|████████▉ | 269/300 [01:05<00:07,  4.38it/s]Device set to use cuda:0
#  90%|█████████ | 270/300 [01:05<00:07,  4.20it/s]Device set to use cuda:0
#  90%|█████████ | 271/300 [01:05<00:07,  4.06it/s]Device set to use cuda:0
#  91%|█████████ | 272/300 [01:05<00:07,  4.00it/s]Device set to use cuda:0
#  91%|█████████ | 273/300 [01:06<00:06,  3.95it/s]Device set to use cuda:0
#  91%|█████████▏| 274/300 [01:06<00:06,  3.89it/s]Device set to use cuda:0
#  92%|█████████▏| 275/300 [01:06<00:06,  3.89it/s]Device set to use cuda:0
#  92%|█████████▏| 276/300 [01:07<00:06,  3.88it/s]Device set to use cuda:0
#  92%|█████████▏| 277/300 [01:07<00:06,  3.62it/s]Device set to use cuda:0
#  93%|█████████▎| 278/300 [01:07<00:06,  3.65it/s]Device set to use cuda:0
#  93%|█████████▎| 279/300 [01:07<00:06,  3.50it/s]Device set to use cuda:0
#  93%|█████████▎| 280/300 [01:08<00:05,  3.59it/s]Device set to use cuda:0
#  94%|█████████▎| 281/300 [01:08<00:05,  3.67it/s]Device set to use cuda:0
#  94%|█████████▍| 282/300 [01:08<00:04,  3.74it/s]Device set to use cuda:0
#  94%|█████████▍| 283/300 [01:08<00:04,  3.78it/s]Device set to use cuda:0
#  95%|█████████▍| 284/300 [01:09<00:04,  3.79it/s]Device set to use cuda:0
#  95%|█████████▌| 285/300 [01:09<00:03,  3.76it/s]Device set to use cuda:0
#  95%|█████████▌| 286/300 [01:09<00:03,  3.61it/s]Device set to use cuda:0
#  96%|█████████▌| 287/300 [01:10<00:03,  3.65it/s]Device set to use cuda:0
#  96%|█████████▌| 288/300 [01:10<00:03,  3.67it/s]Device set to use cuda:0
#  96%|█████████▋| 289/300 [01:10<00:03,  3.57it/s]Device set to use cuda:0
#  97%|█████████▋| 290/300 [01:10<00:02,  3.55it/s]Device set to use cuda:0
#  97%|█████████▋| 291/300 [01:11<00:02,  3.61it/s]Device set to use cuda:0
#  97%|█████████▋| 292/300 [01:11<00:02,  3.59it/s]Device set to use cuda:0
#  98%|█████████▊| 293/300 [01:11<00:02,  3.47it/s]Device set to use cuda:0
#  98%|█████████▊| 294/300 [01:12<00:01,  3.38it/s]Device set to use cuda:0
#  98%|█████████▊| 295/300 [01:12<00:01,  3.45it/s]Device set to use cuda:0
#  99%|█████████▊| 296/300 [01:12<00:01,  3.64it/s]Device set to use cuda:0
#  99%|█████████▉| 297/300 [01:12<00:00,  4.07it/s]Device set to use cuda:0
#  99%|█████████▉| 298/300 [01:12<00:00,  4.30it/s]Device set to use cuda:0
# 100%|█████████▉| 299/300 [01:13<00:00,  4.61it/s]Device set to use cuda:0
# 100%|██████████| 300/300 [01:13<00:00,  4.09it/s]
# Accuracy: 0.530
# Accuracy for label negative: 0.671
# Accuracy for label positive: 0.373
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.54      0.67      0.60       158
#     positive       0.50      0.37      0.43       142
#
#     accuracy                           0.53       300
#    macro avg       0.52      0.52      0.51       300
# weighted avg       0.53      0.53      0.52       300
#
#
# Confusion Matrix:
# [[106  52]
#  [ 89  53]]
